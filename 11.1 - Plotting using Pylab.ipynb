# %%
#Code is not my own; I'm studying my way through the book: Introduction to Computation and Programming Using Python by John Guttag

'''This code is serving as a reference for future programming.'''
# Out:
# 'This code is serving as a reference for future programming.'

# %%
import pylab as plt

'''set line width'''
pylab.rcParams['lines.linewidth'] = 4

'''set font size for titles'''
pylab.rcParams['axes.titlesize'] = 20

'''set font size for labels on axes'''
pylab.rcParams['axes.labelsize'] = 20

'''set size of numbers on x-axis'''
pylab.rcParams['xtick.labelsize'] = 16

'''set size of ticks on x-axis'''
pylab.rcParams['xtick.major.size'] = 7

'''set size of ticks on y-axis'''
pylab.rcParams['ytick.major.size'] = 7

'''set size of markers, e.g., circles representing points'''
pylab.rcParams['lines.markersize'] = 10

'''set number of times marker is shown when displaying legend'''
pylab.rcParams['legend.numpoints'] = 1

# %%
principal = 10000
interestRate = 0.05
years = 20
values = []
for i in range(years + 1):
    values.append(principal)
    principal += principal*interestRate  

plt.figure(figsize=(15,8))
pylab.plot(values)
pylab.title('5% Growth, Compounded Annually', fontsize='xx-large', color='r')
pylab.xlabel('Years of Compounding', fontsize = 'xx-large', color='r')
pylab.ylabel('Value of Principal ($)', fontsize = 'xx-large', color='r')
# Out:
# Text(0, 0.5, 'Value of Principal ($)')

# %%
Value_by_Year = {i: int(values[i]) for i in range(21)}
Value
# Out:
# {0: 10000,
#  1: 10500,
#  2: 11025,
#  3: 11576,
#  4: 12155,
#  5: 12762,
#  6: 13400,
#  7: 14071,
#  8: 14774,
#  9: 15513,
#  10: 16288,
#  11: 17103,
#  12: 17958,
#  13: 18856,
#  14: 19799,
#  15: 20789,
#  16: 21828,
#  17: 22920,
#  18: 24066,
#  19: 25269,
#  20: 26532}
